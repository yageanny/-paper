# %%
import pandas as pd

df = pd.read_csv('明星信息.csv', encoding='utf-8')
df.head()
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
#   name         englishname            nickname   nation  race zodiac_tyep  \
# 0  赵丽颖  ZhaoLiying，Zanilia  丽颖 颖宝 小赵总 赵小刀 丽颖姐姐       中国    汉族         天秤座
# 1   汪峰                 NaN                 NaN  中华人民共和国     汉         巨蟹座
# 2   沈腾                 NaN                 NaN       中国    汉族         天秤座
# 3  黄秋生        AnthonyPerry                 NaN       中国  中英混血         处女座
# 4  郑伊健           EkinCheng               伊健 伊面       中国    汉族         天秤座
#
#   blood_type height weight  birthsite     birthday   occupation  \
# 0         A型  165cm  446kg     河北省廊坊市  1987年10月16日        演员 歌手
# 1         A型  176cm    NaN     北京市丰台区  1971年06月29日       歌手 音乐人
# 2        NaN  180cm    NaN  黑龙江省齐齐哈尔市  1979年10月23日     编剧 导演 演员
# ...

# %%
###########分词方案一：

import pandas as pd
import jieba

df = pd.read_csv('明星信息.csv', encoding='gbk')


stop_list = []
with open('停用词表.txt', 'r', encoding='utf-8') as f:
    for line in f.readlines():
         stop_list.append(line.replace('\n', ''))

cut = open('cut.csv', 'w', encoding='utf-8')

for idx, row in df.iterrows():
    words= jieba.cut(str(row['judge']))

    for word in words:
        if word not in stop_list:
            cut.write(word + ' ')
        else:
            print(word)
            
    cut.write('\n')

cut.close()
df['judge_cut']=''

# %%
###########分词方案二：
import pandas as pd
import jieba
#df = pd.read_csv('明星信息.csv', encoding='utf-8')

stop_list = [' ']
with open('停用词表.txt', 'r', encoding='utf-8') as f:
    for line in f.readlines():
         stop_list.append(line.replace('\n', ''))

data_list = []
for i in df['judge']:
    data_list_temporary = [x if x not in stop_list else '' for x in jieba.cut(str(i))]
    while '' in data_list_temporary:
        data_list_temporary.remove('')
        
    data_list_temporary_str = str(data_list_temporary)[1:-1].replace("'", '').replace(",", '')
    data_list.append(data_list_temporary_str)

print(data_list)
# df['judge_cut'] =  data_list  
# df.to_csv('明星信息1.csv')

# %%
for i in df['judge']:
    data_list_temporary=[]
    for x in jieba.cut(str(i)):
        print(x)
        if x not in stop_list:
            data_list_temporary.append(x)
        else:
            pass
    #data_list_temporary = [x if x not in stop_list else '' for x in jieba.cut(str(i))]

# %%
print( data_list_temporary)
