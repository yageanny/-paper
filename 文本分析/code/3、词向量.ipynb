# %%
import logging
import six
import sys
import gensim
import warnings
from collections import Counter
import gensim as gensim
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from gensim.models.word2vec import LineSentence
import jieba

import re

# %matplotlib inline
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
import os
os.environ['OPENBLAS_NUM_THREADS'] = '1'

# %% [markdown]
# import os
# os.environ['OPENBLAS_NUM_THREADS'] = '1',tnes无法解决啊啊啊啊好痛苦

# %% [markdown]
# ###直接调用训练好的词向量  人民日报
# from gensim.models.keyedvectors import KeyedVectors
# word_vectors = KeyedVectors.load_word2vec_format('F:/data/tdata/sgns.renmin.txt', binary=False)

# %% [markdown]
# from gensim.models import KeyedVectors
# word_vectors  = KeyedVectors.load_word2vec_format('E:/word/sgns.literature.word.bz2', binary=False)

# %%
from gensim.models import KeyedVectors
word_vectors  = KeyedVectors.load_word2vec_format('D:\wenben\8月12下午 文本分析\sgns.literature.bigram-char', binary=False)

# %% [markdown]
# 可以试试D:\wenben\8月12下午 文本分析\sgns.literature.word\sgns.literature.word

# %%
# 设置中文字体路径
chinese_font_path = 'C:/Windows/Fonts/simkai.ttf'
# 导入 matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# 加载中文字体
chinese_font = fm.FontProperties(fname=chinese_font_path)

# %% [markdown]
# 可以回去下载一下试一下，想问一下

# %%
wv2 = word_vectors.most_similar(u"兰州", topn=20)  # 20个最相关的
print(u"和【兰州】最相关的20个词：\n")
for word in wv2:
    print(word[0], word[1])
print("-----\n")

# %%
wv2 = word_vectors.most_similar(u"甘肃", topn=20)  # 20个最相关的
print(u"和【甘肃】最相关的20个词：\n")
for word in wv2:
    print(word[0], word[1])
print("-----\n")
# Out:
# 和【甘肃】最相关的20个词：
#
# 甘肃省 0.7225412726402283
# 宁夏 0.6803792715072632
# 岷县 0.6686451435089111
# 临洮 0.6633148193359375
# 菏泽 0.6610598564147949
# 洮州 0.6572771072387695
# 潍县 0.655208945274353
# 崞 0.6549521684646606
# 西康 0.6544658541679382
# 陕西 0.6518256664276123
# 砀山 0.6511025428771973
# 甘肃人 0.6463677883148193
# 甘州 0.6446126103401184
# 武威 0.6438972353935242
# 闽粤 0.6411128044128418
# 赣县 0.6408620476722717
# 陇东 0.6397392749786377
# 闽浙 0.6391468048095703
# 甘南 0.6367040276527405
# 郴州 0.6360698342323303
# -----

# %%
wv2 = word_vectors.most_similar(u"百度", topn=20)  # 20个最相关的
print(u"和【百度】最相关的20个词：\n")
for word in wv2:
    print(word[0], word[1])
print("-----\n")
# Out:
# 和【百度】最相关的20个词：
#
# 腾讯 0.6199362874031067
# BAT 0.5927181243896484
# 贴吧 0.5788369178771973
# 奇虎 0.577629029750824
# 搜狗 0.5576536655426025
# 百度公司 0.5566093921661377
# 搜狐 0.5477172136306763
# 网易 0.5457697510719299
# 优酷网 0.542261004447937
# 糯米网 0.540283203125
# 搜索引擎 0.5363065004348755
# 土豆网 0.5316785573959351
# 应用程序 0.530573844909668
# 人人网 0.5304474830627441
# LBS 0.5290228724479675
# 风温由 0.5289266109466553
# App 0.5285270810127258
# 苹果应用商店 0.528480589389801
# 搜索框 0.518974244594574
# 优酷 0.518169641494751
# -----

# %%
wv2 = word_vectors.most_similar(u"华中科技大学", topn=20)  # 20个最相关的
print(u"和【华中科技大学】最相关的20个词：\n")
for word in wv2:
    print(word[0], word[1])
print("-----\n")
# Out:
# 和【华中科技大学】最相关的20个词：
#
# 西安电子科技大学 0.6746385097503662
# 武汉理工大学 0.6736884713172913
# 东南大学 0.6620356440544128
# 南京工业大学 0.6579621434211731
# 中南大学 0.6552565097808838
# 华中科大 0.6531168222427368
# 湖南师范大学 0.6524401903152466
# 西南科技大学 0.6509807109832764
# 材料学院 0.6508315205574036
# 生命学院 0.6503276824951172
# 华南理工大学 0.6482797861099243
# 北京科技大学 0.6446981430053711
# 华北电力大学 0.6420555114746094
# 电子科技大学 0.6377374529838562
# 北京理工大学 0.6324993371963501
# 南京财经大学 0.6272202730178833
# 建筑学系 0.6258431673049927
# 陈婧 0.6250656247138977
# 南京邮电大学 0.6226168274879456
# 旅游系 0.6202101707458496
# -----

# %%
wv2 = word_vectors.most_similar(u"兰州大学", topn=20)  # 20个最相关的
print(u"和【兰州大学】最相关的20个词：\n")
for word in wv2:
    print(word[0], word[1])
print("-----\n")
# Out:
# 和【兰州大学】最相关的20个词：
#
# 内蒙古农业大学 0.64217209815979
# 湖北大学 0.6369290351867676
# 宁夏大学 0.6315649747848511
# 经济学系 0.6295349597930908
# 西南大学 0.6285501718521118
# 数学力学系 0.6178983449935913
# 陕西师范大学 0.6165448427200317
# 福州大学 0.6163474321365356
# 四川师范大学 0.6161370873451233
# 武汉工业大学 0.613633930683136
# 石河子大学 0.6122087240219116
# 研究生部 0.6121171116828918
# 贵州大学 0.6113371253013611
# 湖南师范大学 0.6110628843307495
# 任继周 0.6101771593093872
# 西北师范大学 0.6101294159889221
# 数学科学学院 0.6101162433624268
# 华北电力大学 0.6087483167648315
# 西北民族大学 0.6085972785949707
# 顾秉林 0.6083161234855652
# -----

# %%
wv2 = word_vectors.most_similar(u"社科院", topn=20)  # 20个最相关的
print(u"和【社科院】最相关的20个词：\n")
for word in wv2:
    print(word[0], word[1])
print("-----\n")
# Out:
# 和【社科院】最相关的20个词：
#
# 中国社科院 0.7163364887237549
# 中国社会科学院 0.6738505959510803
# 社会科学院 0.6710268259048462
# 社会学所 0.6678988337516785
# 孙元明 0.6413918733596802
# 梁启东 0.6352035999298096
# 社会学研究所 0.6274921894073486
# 农村发展所 0.6258655786514282
# 刘道兴 0.6253546476364136
# 世经所 0.6230249404907227
# 工经所 0.6206804513931274
# 北京市社会科学院 0.6171122789382935
# 农发所 0.6156880855560303
# 财贸所 0.6155264377593994
# 马列所 0.6148092150688171
# 法学所 0.6141024827957153
# 江苏省社科院 0.6133836507797241
# 台研所 0.6093935370445251
# 中国边疆史地研究中心 0.6063185930252075
# 四川省社科院 0.6019394397735596
# -----

# %%
wv2 = word_vectors.most_similar(u"社会学", topn=20)  # 20个最相关的
print(u"和【社会学】最相关的20个词：\n")
for word in wv2:
    print(word[0], word[1])
print("-----\n")
# Out:
# 和【社会学】最相关的20个词：
#
# 历史学 0.703485369682312
# 经济学 0.6944149136543274
# 宗教学 0.6922945976257324
# 法学 0.6868265271186829
# 比较文学 0.6868042349815369
# 社会心理学 0.6863694787025452
# 民俗学 0.6836918592453003
# 发展经济学 0.6827443242073059
# 伦理学 0.6814084053039551
# 政治学 0.6794657707214355
# 文艺学 0.6736794114112854
# 人类学 0.6717830896377563
# 经济学说 0.670441210269928
# 人口学 0.6616834402084351
# 图书馆学 0.6602093577384949
# 民族学 0.6576277017593384
# 行政管理学 0.6574132442474365
# 法律学 0.6548317670822144
# 史学 0.6535594463348389
# 财政学 0.6531257629394531
# -----

# %%
print(word_vectors)
# 计算两个词的相似度/相关程度
try:
    y1 = word_vectors.similarity(u"社科院", u"社会学")
except KeyError:
    y1 = 0
print(u"【社科院】和【社会学】的相似度为：", y1)
print("-----\n")
# Out:
# ...
# 【社科院】和【社会学】的相似度为： 0.4704938
# -----

# %%
print(word_vectors)
# 计算两个词的相似度/相关程度
try:
    y1 = word_vectors.similarity(u"北京大学", u"社会学")
except KeyError:
    y1 = 0
print(u"【北京大学】和【社会学】的相似度为：", y1)
print("-----\n")
# Out:
# ...
# 【北京大学】和【社会学】的相似度为： 0.44370875
# -----

# %%
print(word_vectors)
# 计算两个词的相似度/相关程度
try:
    y1 = word_vectors.similarity(u"中山大学", u"社会学")
except KeyError:
    y1 = 0
print(u"【中山大学】和【社会学】的相似度为：", y1)
print("-----\n")
# Out:
# ...
# 【中山大学】和【社会学】的相似度为： 0.38379064
# -----

# %%
print(word_vectors)
# 计算两个词的相似度/相关程度
try:
    y1 = word_vectors.similarity(u"南京大学", u"社会学")
except KeyError:
    y1 = 0
print(u"【南京大学】和【社会学】的相似度为：", y1)
print("-----\n")
# Out:
# ...
# 【南京大学】和【社会学】的相似度为： 0.41460907
# -----

# %%
print(word_vectors)
# 计算两个词的相似度/相关程度
try:
    y1 = word_vectors.similarity(u"华中科技大学", u"社会学")
except KeyError:
    y1 = 0
print(u"【华中科技大学】和【社会学】的相似度为：", y1)
print("-----\n")
# Out:
# ...
# 【华中科技大学】和【社会学】的相似度为： 0.3336188
# -----

# %%
print(word_vectors)
# 计算两个词的相似度/相关程度
try:
    y1 = word_vectors.similarity(u"百度", u"社会学")
except KeyError:
    y1 = 0
print(u"【百度】和【社会学】的相似度为：", y1)
print("-----\n")
# Out:
# ...
# 【百度】和【社会学】的相似度为： 0.093279205
# -----

# %%
# 寻找不合群的词
y4 =word_vectors.doesnt_match(u"社会学 经济学 哲学 物理学".split())
print(u"不合群的词：", y4)
print("-----\n")
# Out:
# 不合群的词： 物理学
# -----
# D:\annacoda\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
import numpy as np
import matplotlib.pyplot as plt
from gensim.models.keyedvectors import KeyedVectors

# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from whatlies import EmbeddingSet

# %% [markdown]
# 简单版本，只需要呈现

# %%
# 示例词汇
words_to_visualize = ['足球', '篮球', '游泳']

# 获取词向量
embedding_data = [word_vectors[word] for word in words_to_visualize]
# 提取词向量的 x 和 y 分量
x = [emb[0] for emb in embedding_data]
y = [emb[1] for emb in embedding_data]
# 创建 Matplotlib 图表
plt.figure(figsize=(8, 6))
plt.scatter(x, y, marker='o', color='blue')
for i, word in enumerate(words_to_visualize):
    plt.scatter(x[i], y[i], color='red')  # 点的颜色为红色
    plt.annotate(word, (x[i], y[i]), fontsize=12)

# 添加标签
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Word Embedding Visualization')
plt.grid(True)
plt.show()
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 36275 (\N{CJK UNIFIED IDEOGRAPH-8DB3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 29699 (\N{CJK UNIFIED IDEOGRAPH-7403}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 31726 (\N{CJK UNIFIED IDEOGRAPH-7BEE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 27891 (\N{CJK UNIFIED IDEOGRAPH-6CF3}) missing from current font.
# ...

# %%
print(embedding_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
from gensim.models import KeyedVectors
from sklearn.manifold import TSNE
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# %%
# 示例词汇
words_to_visualize = ['足球', '篮球', '游泳', '女人', '男人']
# 获取词向量
embedding_data = [word_vectors[word] for word in words_to_visualize]
# 提取词向量的 x 和 y 分量
x = [emb[0] for emb in embedding_data]
y = [emb[1] for emb in embedding_data]
# 提取"女人"和"男人"的词向量
woman_embedding = embedding_data[3]  # 女人
man_embedding = embedding_data[4]    # 男人

# %% [markdown]
# 不要忘记定义word—vectors

# %%
# 计算其他词汇相对于"女人"和"男人"的差异
diff_embeddings = [emb - woman_embedding for emb in embedding_data]  # 相对于女人的差异
diff_embeddings = np.array(diff_embeddings)

# %%
# 使用PCA降维
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(diff_embeddings)

# %%
# 创建 Matplotlib 图表
plt.figure(figsize=(8, 6))
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], marker='o', color='blue')

# 标记词汇并添加标签
# 标记词汇并添加标签
for i, word in enumerate(words_to_visualize):
    plt.scatter(reduced_embeddings[i, 0], reduced_embeddings[i, 1], color='red')
    plt.annotate(word, (reduced_embeddings[i, 0], reduced_embeddings[i, 1]), fontsize=12,
                 xytext=(-10, 5), textcoords='offset points', fontproperties=chinese_font)  # 使用中文字体

# 添加标签
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.title('PCA-based Word Embedding Visualization')
plt.grid(True)
plt.show()

# %%
# 获取词向量
embedding_data = [word_vectors[word] for word in words_to_visualize]

# 将词向量转换为numpy数组
embedding_array = np.array(embedding_data)

# 使用PCA进行降维
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embedding_array)

# 绘制散点图
plt.figure(figsize=(10, 6))
plt.scatter(pca_result[:, 0], pca_result[:, 1], color='blue')
for i, word in enumerate(words_to_visualize):
    plt.annotate(word, (reduced_embeddings[i, 0], reduced_embeddings[i, 1]), fontsize=12,
                 xytext=(-10, 5), textcoords='offset points', fontproperties=chinese_font)

plt.xlabel('PCA Dimension 1')
plt.ylabel('PCA Dimension 2')
plt.title('Word Embedding Visualization with PCA')
plt.grid()
plt.show()

# %%
# 获取词向量
word_vectors = [word_vectors[word] for word in words_to_visualize]

# %%
# 用于绘制的词汇列表
words_to_visualize = ['男人', '女人', '篮球', '足球', '学生']
# 获取词向量
word_vectors = [word_vectors[word] for word in words_to_visualize]

# %%
# 计算词向量之间的余弦相似度
similarity_matrix = cosine_similarity(word_vectors)
print(similarity_matrix)
# 使用PCA降维
pca = PCA(n_components=2)
pca_result = pca.fit_transform(similarity_matrix)

# 绘制词汇点
plt.scatter(pca_result[:, 0], pca_result[:, 1], color='b')
for i, word in enumerate(words_to_visualize):
    plt.annotate(word, (pca_result[i, 0], pca_result[i, 1]), fontproperties=chinese_font)

# 绘制连接线和标注关系强度
for i in range(len(words_to_visualize)):
    for j in range(i + 1, len(words_to_visualize)):
        plt.plot([pca_result[i, 0], pca_result[j, 0]],
                 [pca_result[i, 1], pca_result[j, 1]],
                 color='gray', linestyle='-', linewidth=similarity_matrix[i, j] * 5)

plt.xlabel('PCA Dimension 1')
plt.ylabel('PCA Dimension 2')
plt.title('Word Embedding Visualization with Relationships')
plt.show()
# Out:
# [[1.         0.78437984 0.20491603 0.18806465 0.17146958 0.13629918]
#  [0.78437984 0.9999999  0.14539418 0.11483981 0.19600806 0.17547531]
#  [0.20491603 0.14539418 1.0000002  0.6379039  0.28962666 0.27211484]
#  [0.18806465 0.11483981 0.6379039  0.99999994 0.28795198 0.15056342]
#  [0.17146958 0.19600806 0.28962666 0.28795198 0.99999976 0.5712403 ]
#  [0.13629918 0.17547531 0.27211484 0.15056342 0.5712403  1.        ]]

# %%
if len(words_to_visualize) != len(embedding_data):
    print("长度不一致！")
else:
    print("长度一致！")
print("示例词汇列表长度:", len(words_to_visualize))
print("词向量列表长度:", len(embedding_data))
print("示例词汇列表:", words_to_visualize)
# Out:
# 长度一致！
# 示例词汇列表长度: 5
# 词向量列表长度: 5
# 示例词汇列表: ['男人', '女人', '篮球', '足球', '学生']

# %%
import pandas as pd
# 计算余弦相似度矩阵
cosine_matrix = cosine_similarity(embedding_data)

# 构建表格
similarity_table = pd.DataFrame(cosine_matrix, columns=words_to_visualize, index=words_to_visualize)
print(similarity_table)
# Out:
#           男人        女人        篮球        足球        学生
# 男人  1.000000  0.637904  0.405432  0.114840  0.188065
# 女人  0.637904  1.000000  0.371119  0.145394  0.204916
# 篮球  0.405432  0.371119  1.000000  0.166769  0.143848
# 足球  0.114840  0.145394  0.166769  1.000000  0.784380
# 学生  0.188065  0.204916  0.143848  0.784380  1.000000

# %%
# 创建图表
plt.figure(figsize=(8, 6))

# 绘制点
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], marker='o', color='blue')

# 标记词汇并添加标签


# 添加标签等其他设置...

# %%
len(vectors_array)
# Out:
# 5

# %%
# 使用 t-SNE 进行降维
from sklearn.manifold import TSNE
tsne = TSNE(n_components=3, perplexity=0.1, random_state=42)
embedded_vectors = tsne.fit_transform(vectors_array)

# %%
def T_SNE(X,Label,Component=2,title=""):

    tsne = TSNE(n_components=Component)

    tsne_result = tsne.fit_transform(X)
   
    tsne_result_df = pd.DataFrame({'T_SNE_1': tsne_result[:,0], 'T_SNE_2': tsne_result[:,1], 
                                   'label': Label})
    lim = (tsne_result.min()-0.1*tsne_result.min(), tsne_result.max()+0.1*tsne_result.min())
    
    PLOT(TITLE=title,Product="T_SNE",Label=Label,Data=tsne_result_df,lim=lim)

    return tsne_result,tsne
    

result,tsne=T_SNE(X='女人',Label='男人',Component=2,title="Digit_data")

# %%
# 创建 Matplotlib 图表
plt.figure(figsize=(8, 6))
plt.scatter(embedded_vectors[:, 0], embedded_vectors[:, 1], marker='o', color='blue')

# 标记词汇并添加标签
for i, word in enumerate(words_to_visualize):
    plt.scatter(embedded_vectors[i, 0], embedded_vectors[i, 1], color='red')  # 点的颜色为红色
    plt.annotate(word, (embedded_vectors[i, 0], embedded_vectors[i, 1]), fontsize=12)

# 添加标签
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Word Embedding Visualization')
plt.grid(True)
plt.show()

# %%
# 选择词语
words_to_visualize = ['足球', '篮球', '游泳', '跑步']

# 获取词向量
word_vectors_to_visualize = [word_vectors[word] for word in words_to_visualize]

word_vectors_array = np.array(word_vectors_to_visualize)

# %%
# 使用 t-SNE 进行降维
tsne = TSNE(n_components=2, random_state=42)
embedded_vectors = tsne.fit_transform(word_vectors_to_visualize)

# 绘制可视化
plt.figure(figsize=(10, 6))
plt.scatter(embedded_vectors[:, 0], embedded_vectors[:, 1])
for i, word in enumerate(words_to_visualize):
    plt.annotate(word, (embedded_vectors[i, 0], embedded_vectors[i, 1]))
plt.title('Word Embedding Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# %%
# 使用 t-SNE 进行降维，降低 perplexity 的值
tsne = TSNE(n_components=2, perplexity=1, random_state=42)

# %%
embedded_vectors = tsne.fit_transform(word_vectors_array)

# %%
import os
os.environ['OPENBLAS_NUM_THREADS'] = '1'

# %%
print(x)
print(y)
type(word_vectors_array)
word_vectors_array.shape
# Out:
# [-0.027347, -0.228249, -0.0852, -0.015011, 0.16138]
# [0.070783, -0.467796, -0.034392, 0.425863, 0.507455]
# (4, 300)

# %%
from whatlies import EmbeddingSet
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

x = [emb[0] for emb in embedding_data]
y = [emb[1] for emb in embedding_data]

# 创建EmbeddingSet对象
emb = EmbeddingSet(*embedding_data, words=words_to_visualize)

# 创建 Matplotlib 图表
plt.figure(figsize=(8, 6))
plt.scatter(x, y, marker='o', color='blue')

# 使用PCA进行降维
pca = PCA(n_components=2)
pca_result = pca.fit_transform(emb.to_X())

# 绘制散点图
plt.figure(figsize=(10, 6))
plt.scatter(pca_result[:, 0], pca_result[:, 1], color='blue')
for i, word in enumerate(words_to_visualize):
    plt.annotate(word, (pca_result[i, 0], pca_result[i, 1]), fontsize=12)

plt.xlabel('PCA Dimension 1')
plt.ylabel('PCA Dimension 2')
plt.title('Word Embedding Visualization with PCA')
plt.grid()
plt.show()

# %%
import umap.umap_ as umap
import matplotlib.pyplot as plt

# %%
# 示例词汇
words_to_v = ['爱情', '友情',  '亲情', '快乐', '伤心', '信任','金钱']

# 获取词向量
embedding_data = [word_vectors[word] for word in words_to_v]

# %%
# 使用UMAP进行降维
reducer = umap.UMAP(n_components=2)
embedded_vectors = reducer.fit_transform(embedding_data)
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\umap\umap_.py:2344: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(

# %%
# 绘制散点图
plt.figure(figsize=(10, 6))
plt.scatter(embedded_vectors[:, 0], embedded_vectors[:, 1], c='blue')

# 添加词汇标签
for i, word in enumerate(words_to_v):
    plt.annotate(word, (embedded_vectors[i, 0], embedded_vectors[i, 1]),fontproperties=chinese_font)

plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.title('Cultural Dimensions Visualization using UMAP')
plt.show()

# %% [markdown]
# 三个维度的

# %%
from mpl_toolkits import mplot3d

# %%
# 创建一个 3D 图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制三维数据
ax.scatter3D(x, y, z, c=colors, cmap='viridis')

# 设置坐标轴标签
ax.set_xlabel('UMAP Dimension 1')
ax.set_ylabel('UMAP Dimension 2')
ax.set_zlabel('UMAP Dimension 3')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-d2a1598ec905> in <module>
#       4
#       5 # 绘制三维数据
# ----> 6 ax.scatter3D(x, y, z, c=colors, cmap='viridis')
#       7
#       8 # 设置坐标轴标签
#
# NameError: name 'x' is not defined

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
print("Individualism Vector Shape:", individualism_vector.shape)
print("Collectivism Vector Shape:", collectivism_vector.shape)
# Out:
# Individualism Vector Shape: (300,)
# Collectivism Vector Shape: (300,)

# %%
# 示例词汇
word_list = ['爱情', '友情', '亲情', '快乐', '伤心', '信任', '金钱']  # 你的词汇列表

# 加载个体主义和集体主义的词向量
individualism_vector = word_vectors['自私']
collectivism_vector = word_vectors['奉献']

# 计算词汇与个体主义和集体主义的相似度
individualism_similarity = [cosine_similarity([individualism_vector], [word_vectors[word]])[0][0] for word in word_list]
collectivism_similarity = [cosine_similarity([collectivism_vector], [word_vectors[word]])[0][0] for word in word_list]

# 输出词汇在个体主义和集体主义维度上的相似度分数
for word, ind_sim, col_sim in zip(word_list, individualism_similarity, collectivism_similarity):
    print(f"Word: {word}, Individualism Similarity: {ind_sim:.2f}, Collectivism Similarity: {col_sim:.2f}")
# Out:
# Word: 爱情, Individualism Similarity: 0.31, Collectivism Similarity: 0.36
# Word: 友情, Individualism Similarity: 0.25, Collectivism Similarity: 0.37
# Word: 亲情, Individualism Similarity: 0.30, Collectivism Similarity: 0.28
# Word: 快乐, Individualism Similarity: 0.30, Collectivism Similarity: 0.26
# Word: 伤心, Individualism Similarity: 0.33, Collectivism Similarity: 0.25
# Word: 信任, Individualism Similarity: 0.35, Collectivism Similarity: 0.32
# Word: 金钱, Individualism Similarity: 0.27, Collectivism Similarity: 0.34

# %%
import matplotlib.pyplot as plt


# 创建散点图
plt.figure(figsize=(10, 6))
plt.scatter(individualism_similarity, collectivism_similarity, c='blue', marker='o')

# 添加标签
for i, word in enumerate(word_list):
    plt.annotate(word, (individualism_similarity[i], collectivism_similarity[i]), textcoords="offset points", xytext=(0, 10), ha='center',fontproperties=chinese_font)

# 设置图标题和轴标签
plt.title('自私与奉献',fontproperties=chinese_font)
plt.xlabel('自私',fontproperties=chinese_font)
plt.ylabel('奉献',fontproperties=chinese_font)

# 显示图形
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# ... 其他代码 ...

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity


from gensim.models import KeyedVectors
word_vectors  = KeyedVectors.load_word2vec_format('D:\wenben\8月12下午 文本分析\sgns.literature.bigram-char', binary=False)

# 设置中文字体路径
chinese_font_path = 'C:/Windows/Fonts/simkai.ttf'
# 导入 matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# 加载中文字体
chinese_font = fm.FontProperties(fname=chinese_font_path)

# 示例词汇
word_list = ['爱情', '友情', '亲情', '快乐', '伤心', '信任', '金钱']  # 你的词汇列表

# 加载个体主义和集体主义的词向量
individualism_vector = word_vectors['自私']
collectivism_vector = word_vectors['奉献']

# 计算词汇与个体主义和集体主义的相似度
individualism_similarity = [cosine_similarity([individualism_vector], [word_vectors[word]])[0][0] for word in word_list]
collectivism_similarity = [cosine_similarity([collectivism_vector], [word_vectors[word]])[0][0] for word in word_list]

# 输出词汇在个体主义和集体主义维度上的相似度分数
for word, ind_sim, col_sim in zip(word_list, individualism_similarity, collectivism_similarity):
    print(f"Word: {word}, Individualism Similarity: {ind_sim:.2f}, Collectivism Similarity: {col_sim:.2f}")

# 绘制词汇与个体主义和集体主义的相似度散点图
plt.scatter(individualism_similarity, collectivism_similarity, color='blue', label='Vocabulary')
plt.scatter(individualism_similarity[2], collectivism_similarity[2], color='red', label='友情', s=100, marker='x')  # 以友情词汇为红色叉号

# 添加连线和词汇标签
for i, word in enumerate(words_to_v):
    if i != 2:  # 跳过信任词汇本身
        plt.arrow(individualism_similarity[2], collectivism_similarity[2], individualism_similarity[i] - individualism_similarity[2], collectivism_similarity[i] - collectivism_similarity[2], head_width=0.02, color='gray', alpha=0.5)
        plt.annotate(word, (individualism_similarity[i], collectivism_similarity[i]), textcoords="offset points", xytext=(0,10), ha='center',fontproperties=chinese_font)

# 设置图标题和轴标签
plt.title('自私与奉献',fontproperties=chinese_font)
plt.xlabel('自私',fontproperties=chinese_font)
plt.ylabel('奉献',fontproperties=chinese_font)
# Out:
# Text(0, 0.5, '奉献')

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# 假设你已经加载了词向量模型并拥有了相应的词汇列表和词向量
# 例如，你有一个名为 word_vectors 的字典，包含了词汇和对应的词向量

# 创建一个空的有向图
G = nx.DiGraph()

# 添加信任节点
G.add_node("信任")

# 添加其他词汇节点，并连接到信任节点
for word in ["诚实", "可靠", "友好", "欺骗", "背叛"]:
    G.add_node(word)
    G.add_edge("信任", word)

# 绘制节点和边
pos = nx.spring_layout(G)  # 使用 Spring layout 进行布局
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)

# 添加节点名称
node_labels = {node: node for node in G.nodes()}
nx.draw_networkx_labels(G, pos, labels=node_labels)

# 显示图表
plt.title("Trust and Related Words")
plt.show()
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 35802 (\N{CJK UNIFIED IDEOGRAPH-8BDA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 21487 (\N{CJK UNIFIED IDEOGRAPH-53EF}) missing from current font.
# ...

# %% [markdown]
# 颜色代码，三维

# %%
freedom_vector = word_vectors['自由']

# 添加自由维度的相似度
freedom_similarity = [cosine_similarity([freedom_vector], [word_vectors[word]])[0][0] for word in word_list]

# 绘制词汇与个体主义和集体主义的相似度散点图
plt.scatter(individualism_similarity, collectivism_similarity, c=freedom_similarity, cmap='coolwarm', label='Vocabulary')
plt.scatter(individualism_similarity[2], collectivism_similarity[2], color='red', label='Trust', s=100, marker='x')  # 以信任词汇为红色叉号

# 添加连线和词汇标签
for i, word in enumerate(words_to_v):
    if i != 2:  # 跳过信任词汇本身
        plt.arrow(individualism_similarity[2], collectivism_similarity[2], individualism_similarity[i] - individualism_similarity[2], collectivism_similarity[i] - collectivism_similarity[2], head_width=0.02, color='gray', alpha=0.5)
        plt.annotate(word, (individualism_similarity[i], collectivism_similarity[i]), textcoords="offset points", xytext=(0,10), ha='center')

# 设置颜色标签
cb = plt.colorbar()
cb.set_label('Freedom Similarity', rotation=270, labelpad=15)
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 29233 (\N{CJK UNIFIED IDEOGRAPH-7231}) missing from current font.
#   func(*args, **kwargs)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 24773 (\N{CJK UNIFIED IDEOGRAPH-60C5}) missing from current font.
#   func(*args, **kwargs)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 21451 (\N{CJK UNIFIED IDEOGRAPH-53CB}) missing from current font.
#   func(*args, **kwargs)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 24555 (\N{CJK UNIFIED IDEOGRAPH-5FEB}) missing from current font.
#   func(*args, **kwargs)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# 三维代码三维图

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制个体主义、集体主义和自由三个维度的散点图
ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c='green', marker='o', label='Vocabulary')

# 添加词汇标签
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i], word,fontproperties=chinese_font)

# 设置坐标轴标签字体
ax.set_xlabel('自私', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'},fontproperties=chinese_font)
ax.set_ylabel('奉献', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'},fontproperties=chinese_font)
ax.set_zlabel('自由', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)




# 设置图表标题

plt.title('Three-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'},fontproperties=chinese_font)

# ... 其他代码 ...

plt.show()

# 添加词汇标签

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制个体主义、集体主义和自由三个维度的散点图
ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c='green', marker='o', label='Vocabulary')

# 添加词汇标签，并稍微偏移标签位置
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i] +100, word, fontproperties=chinese_font)

# 绘制约束的思维内容
ax.plot([0, 0], [-1, 1], [0, 0], color='red', linestyle='dashed', label='Constraint')  # y轴上的约束

# 设置坐标轴标签字体
ax.set_xlabel('自私', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_ylabel('奉献', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_zlabel('自由', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)

# 设置图表标题
plt.title('Three-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'}, fontproperties=chinese_font)

# ... 其他代码 ...

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制个体主义、集体主义和自由三个维度的散点图
scatter = ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c='green', marker='o', label='生气')

# 添加词汇标签
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i], word, fontproperties=chinese_font)

# 设置坐标轴标签字体
ax.set_xlabel('自私', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_ylabel('奉献', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_zlabel('自由', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)

# 调整观察角度
ax.view_init(elev=50, azim=-45)

# 添加第五个维度的点颜色变化  # 示例第五个维度的值
scatter.set_array(f_similarity)
scatter.set_cmap('plasma')

# 设置图表标题
plt.title('Five-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'}, fontproperties=chinese_font)
ax.legend(prop=chinese_font)
# ... 其他代码 ...

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.font_manager import FontProperties



# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制个体主义、集体主义和自由三个维度的散点图
scatter = ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c=f_similarity, marker='o', label='约束', cmap='plasma')

# 添加词汇标签
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i], word, fontproperties=chinese_font)

# 设置坐标轴标签字体
ax.set_xlabel('自私', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_ylabel('奉献', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_zlabel('自由', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)

# 调整观察角度
ax.view_init(elev=50, azim=-45)

# 设置图表标题
plt.title('Five-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'}, fontproperties=chinese_font)

# 添加图例
ax.legend(prop=chinese_font)

# 显示颜色映射
cbar = plt.colorbar(scatter)
cbar.set_label('Fifth Dimension', fontdict={'fontsize': 0.2, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
cbar.ax.tick_params(labelsize=8)  # 设置颜色映射的图例标签大小
cbar.ax.set_position([0.85,0.2,0.02, 0.5])  # 调整颜色映射图例的大小
# ... 其他代码 ...

plt.show()

# %%
# 创建一个词汇量
trust_vector = word_vectors['信任']
trust_similarity = [cosine_similarity([trust_vector], [word_vectors[word]])[0][0] for word in word_list]

# %%
import plotly.graph_objects as go
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Line3DCollection
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Line3D

# %%
# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制三个维度的散点图
ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c='green', marker='o', label='Vocabulary')

# 添加词汇标签
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i], word, fontproperties=chinese_font)

# 连接词汇
for i in range(len(words_to_v)):
    line = Line3D([individualism_similarity[i], trust_similarity[i]], [collectivism_similarity[i], trust_similarity[i]], [freedom_similarity[i], trust_similarity[i]], c='gray', linestyle='dotted')
    ax.add_line(line)

# ... 其他代码 ...

plt.show()

# %% [markdown]
# 非常抱歉，之前的回答可能导致了一些混淆。这个图实际上在三维空间中表示了每个词在个体主义、集体主义和自由三个维度上的相似度分数。每个词在三个维度上的分数确定了在三维坐标系中的位置。
#
# 连接线的绘制可能在这种情况下不是很适合，因为连接线是在三维空间中绘制的，而且可能会使图表看起来更加复杂。你可能需要考虑使用其他方法来展示词汇之间的关系，例如绘制二维平面图来显示每个词在两个维度上的相似度分数，并使用连线来表示这些词之间的关系。
#
# 如果你想更清楚地了解词汇之间的关系，建议在二维平面图上进行可视化，而不是在三维空间中。这可以通过使用`matplotlib`库中的二维图表功能来实现。你可以将个体主义和集体主义作为两个坐标轴，然后在图上绘制词汇的散点，并使用连线来表示词汇之间的关系。

# %%
f_vector = word_vectors['约束']


print(f_similarity)
# 添加自由维度的相似度
f_similarity = [cosine_similarity([f_vector], [word_vectors[word]])[0][0] for word in word_list]
# Out:
# [0.22907557, 0.18661207, 0.30345038, 0.22352982, 0.1354634, 0.3002978, 0.24523984]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 生成球坐标系的参数
theta = np.linspace(0, np.pi/2, num=50)
phi = np.linspace(0, 2*np.pi, num=50)
theta, phi = np.meshgrid(theta, phi)

# 根据球坐标系参数计算坐标值
x = np.sin(theta) * np.cos(phi)
y = np.sin(theta) * np.sin(phi)
z = np.cos(theta)

# 绘制半球形状的表面
ax.plot_surface(x, y, z, color='c', alpha=0.5)

# 在半球面上展示个体主义、集体主义、自由和第四个维度的数据
ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, f_similarity, cmap='viridis', marker='o', label='Vocabulary')



# 添加词汇标签
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i], word,fontproperties=chinese_font)

# 设置坐标轴标签字体
ax.set_xlabel('Individualism', fontdict={'fontsize': 22, 'fontweight': 'bold', 'color': 'red'},fontproperties=chinese_font)
ax.set_ylabel('Collectivism', fontdict={'fontsize': 22, 'fontweight': 'bold', 'color': 'green'},fontproperties=chinese_font)
ax.set_zlabel('Freedom', fontdict={'fontsize': 22, 'fontweight': 'bold', 'color': 'blue'},fontproperties=chinese_font)

# 添加第四个维度的标签
ax.set_xlabel('Individualism', fontdict={'fontsize': 22, 'fontweight': 'bold', 'color': 'red'},fontproperties=chinese_font)
ax.set_ylabel('Collectivism', fontdict={'fontsize': 22, 'fontweight': 'bold', 'color': 'green'},fontproperties=chinese_font)
ax.set_zlabel('Freedom', fontdict={'fontsize': 22, 'fontweight': 'bold', 'color': 'blue'},fontproperties=chinese_font)
# ... 其他代码 ...

# 添加第四个维度的标签
fourth_dimension_label = 'Fourth Dimension'
plt.title('Four-Dimensional Vocabulary Visualization\n{}'.format(fourth_dimension_label),
          fontdict={'fontsize': 16, 'fontweight': 'bold'},fontproperties=chinese_font)


# ... 其他代码 ...
plt.show()
# Out:
# <ipython-input-44-2d6a63c0c97b>:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, f_similarity, cmap='viridis', marker='o', label='Vocabulary')

# %%
import plotly.graph_objs as go
import numpy as np

# ... 其他代码 ...

# 生成球面上的点
phi = np.linspace(0, np.pi, 30)
theta = np.linspace(0, 2 * np.pi, 60)
phi, theta = np.meshgrid(phi, theta)
x = np.sin(phi) * np.cos(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(phi)

# 创建四维词汇数据（这里只是示例，你需要将其替换为实际的四维数据）
fourth_dimension = np.random.rand(30, 60)

# 创建球面上的散点图
scatter = go.Scatter3d(
    x=x.flatten(),
    y=y.flatten(),
    z=z.flatten(),
    mode='markers',
    marker=dict(
        size=5,
        color=fourth_dimension.flatten(),
        colorscale='Viridis',
        opacity=0.8
    ),
    text=words_to_visualize,
    hoverinfo='text'
)

# 设置图表布局
layout = go.Layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
    ),
    title='Four-Dimensional Vocabulary Visualization on a Sphere'
)

# 创建图表并显示
fig = go.Figure(data=[scatter], layout=layout)
fig.show()

# %%
import numpy as np

# 假设四个维度的权重，示例中使用随机权重
weights = {'自由': 1.0, '约束': -1.0, '自私': -0.1, '奉献': 1.0}

# %%
# 计算词汇在四个维度上的值
dimension_values = {}
for word in word_list:
    dimension_values[word] = {
        '自由': np.random.rand() * weights['自由'],
        '约束': np.random.rand() * weights['约束'],
        '自私': np.random.rand() * weights['自私'],
        '奉献': np.random.rand() * weights['奉献']
    }

# 打印词汇在四个维度上的值
for word, dimensions in dimension_values.items():
    print(f"Word: {word}, Dimension Values: {dimensions}")
# Out:
# Word: 爱情, Dimension Values: {'自由': 0.040714105609571116, '约束': -0.3262748197730121, '自私': -0.009230589329349758, '奉献': 0.850013311822607}
# Word: 友情, Dimension Values: {'自由': 0.41629060549046937, '约束': -0.9595063980537595, '自私': -0.05844988396038473, '奉献': 0.4790046576527298}
# Word: 亲情, Dimension Values: {'自由': 0.6197121344158448, '约束': -0.14782443424428604, '自私': -0.02509807756621342, '奉献': 0.43499757485171575}
# Word: 快乐, Dimension Values: {'自由': 0.32140056268125905, '约束': -0.9409995410533601, '自私': -0.08542862158161948, '奉献': 0.19120477437066308}
# Word: 伤心, Dimension Values: {'自由': 0.5562724666402821, '约束': -0.7054123867282778, '自私': -0.08217259947458572, '奉献': 0.6460799760014606}
# Word: 信任, Dimension Values: {'自由': 0.8024238206801357, '约束': -0.4473369156607342, '自私': -0.020353130694695742, '奉献': 0.2060541191870151}
# Word: 金钱, Dimension Values: {'自由': 0.5536811222570017, '约束': -0.010299029827996908, '自私': -0.07015247236445397, '奉献': 0.03501545327838018}

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 假设你已经有了dimension_values这个字典，包含每个词汇在四个维度上的值

# 创建图形对象
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# 绘制四维数据点的三维投影
for word, dimensions in dimension_values.items():
    ax.scatter(dimensions['自由'], dimensions['约束'], dimensions['自私'], color='black')
    ax.text(dimensions['自由'], dimensions['约束'], dimensions['自私'], word)

# 绘制四维坐标轴的三维投影
ax.quiver(0, 0, 0, 1, 0, 0, color='r', label='自由')
ax.quiver(0, 0, 0, 0, 1, 0, color='g', label='约束')
ax.quiver(0, 0, 0, 0, 0, 1, color='b', label='自私')

# 设置坐标轴标签
ax.set_xlabel('自由')
ax.set_ylabel('约束')
ax.set_zlabel('自私')

# 设置图表标题
plt.title('Three-Dimensional Projection of Four-Dimensional Vocabulary Visualization')

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 假设你已经有了dimension_values这个字典，包含每个词汇在四个维度上的值

# 指定中文字体
chinese_font = {'family': 'SimHei', 'size': 12}

# 创建图形对象
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# 绘制四维数据点的三维投影
for word, dimensions in dimension_values.items():
    ax.scatter(dimensions['自由'], dimensions['约束'], dimensions['自私'], color='black')
    ax.text(dimensions['自由'], dimensions['约束'], dimensions['自私'], word, fontdict=chinese_font)

# 绘制四维坐标轴的三维投影
ax.quiver(0, 0, 0, 1, 0, 0, color='r', label='自由')
ax.quiver(0, 0, 0, 0, 1, 0, color='g', label='约束')
ax.quiver(0, 0, 0, 0, 0, 1, color='b', label='自私')

# 设置坐标轴标签
ax.set_xlabel('自由', fontdict=chinese_font)
ax.set_ylabel('约束', fontdict=chinese_font)
ax.set_zlabel('自私', fontdict=chinese_font)

# 设置图表标题
plt.title('Three-Dimensional Projection of Four-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'}, fontproperties=chinese_font)

plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 假设你已经有了dimension_values这个字典，包含每个词汇在四个维度上的值

# 指定中文字体
chinese_font = {'family': 'SimHei', 'size': 12}

# 创建图形对象
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# 计算投影坐标
x_coords = [dimensions['自由'] for word, dimensions in dimension_values.items()]
y_coords = [-dimensions['约束'] for word, dimensions in dimension_values.items()]  # y轴反向
z_coords = [dimensions['自私'] for word, dimensions in dimension_values.items()]

# 绘制四维数据点的三维投影
ax.scatter(x_coords, y_coords, z_coords, color='black')
for x, y, z, word in zip(x_coords, y_coords, z_coords, dimension_values.keys()):
    ax.text(x, y, z, word, fontdict=chinese_font)

# 绘制四维坐标轴的三维投影
ax.quiver(0, 0, 0, 1, 0, 0, color='r', label='自由')
ax.quiver(0, 0, 0, 0, -1, 0, color='g', label='约束')  # y轴反向
ax.quiver(0, 0, 0, 0, 0, 1, color='b', label='自私')

# 设置坐标轴标签
ax.set_xlabel('自由', fontdict=chinese_font)
ax.set_ylabel('约束', fontdict=chinese_font)
ax.set_zlabel('自私', fontdict=chinese_font)

# 设置图表标题
plt.title('Three-Dimensional Projection of Four-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'}, fontproperties=chinese_font)

plt.legend()

plt.show()

# %%
# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制词汇的散点图，每个维度的值对应三维坐标轴
for word, dimensions in dimension_values.items():
    ax.scatter(dimensions['自由'], dimensions['约束'], dimensions['selfishness'], c='blue', marker='o')
    ax.text(dimensions['自由'], dimensions['约束'], dimensions[''], word)


# 设置坐标轴标签
ax.set_xlabel('Freedom')
ax.set_ylabel('Constraint')
ax.set_zlabel('Selfishness')

# 设置图表标题
plt.title('Three-Dimensional Vocabulary Visualization')

plt.show()

# %%
##文章分类
##对文章按照内容类型进行自动分类，首批支持娱乐、体育、科技等26个主流内容类型，为文章聚类、文本内容分析等应用提供基础技术支持。
#参数名称	类型	详细说明
item	object	分类结果，包含一级与二级分类
+lv1_tag_list	array of objects	一级分类结果
+lv2_tag_list	array of objects	二级分类结果
++score	float	类别标签对应得分，范围0-1
++tag	string	类别标签
##安装
##pip install baidu-aip
##调用相关包
from aip import AipNlp
##常量APP_ID在百度云控制台中创建，常量API_KEY与SECRET_KEY是在创建完毕应用后，系统分配给用户的，均为字符串，用于标识用户，为访问做签名验证，可在AI服务控制台中的应用列表中查看。
##获取说明见链接：https://ai.baidu.com/ai-doc/REFERENCE/Ck3dwjgn3
APP_ID = '***'
API_KEY = '***'
SECRET_KEY = '***'
client = AipNlp(APP_ID, API_KEY, SECRET_KEY)
##词向量表示接口提供中文词向量的查询功能。
word="社会"
client.wordEmbedding(word)
##词义相似度：输入两个词，得到两个词的相似度结果。
result3 = client.wordSimEmbedding("社会","国家")

print(result3)
##短文本相似度接口用来判断两个文本的相似度得分。
result1 = client.simnet("这件衣服颜色怎么样？","这件衣服价格怎么样")

print(result1)
title = "欧洲冠军杯足球赛"

content = "欧洲冠军联赛是欧洲足球协会联盟主办的年度足球比赛，代表欧洲俱乐部足球最高荣誉和水平，被认为是全世界最高素质、最具影响力以及最高水平的俱乐部赛事，亦是世界上奖金最高的足球赛事和体育赛事之一。"

""" 调用文章分类 """
client.topic(title, content)
##评论观点抽取接口用来提取一条评论句子的关注点和评论观点，并输出评论观点标签及评论观点极性。
text = "华为手机拍照很给力"

""" 调用评论观点抽取 """
client.commentTag(text);

""" 如果有可选参数 """
options = {}
options["type"] = 13

""" 带参数调用评论观点抽取 """
client.commentTag(text, options)

# %%
import logging
import six
import sys
import gensim
import warnings
from collections import Counter
import gensim as gensim
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from gensim.models.word2vec import LineSentence
import jieba

import re

# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import os
os.environ['OPENBLAS_NUM_THREADS'] = '1'

# ... 其他代码 ...
#创建二维图还有一个中心方向的
import matplotlib.pyplot as plt
import numpy as np

# ... 其他代码 ...

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity


from gensim.models import KeyedVectors
word_vectors  = KeyedVectors.load_word2vec_format('D:\wenben\8月12下午 文本分析\sgns.literature.bigram-char', binary=False)

# 设置中文字体路径
chinese_font_path = 'C:/Windows/Fonts/simkai.ttf'
# 导入 matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
# 加载中文字体
chinese_font = fm.FontProperties(fname=chinese_font_path)

# 示例词汇
word_list = ['爱情', '友情', '亲情', '快乐', '伤心', '信任', '金钱']  # 你的词汇列表

# 加载个体主义和集体主义的词向量
individualism_vector = ['自私']
collectivism_vector = word_vectors['奉献']

# 计算词汇与个体主义和集体主义的相似度
individualism_similarity = [cosine_similarity([individualism_vector], [word_vectors[word]])[0][0] for word in word_list]
collectivism_similarity = [cosine_similarity([collectivism_vector], [word_vectors[word]])[0][0] for word in word_list]

# 输出词汇在个体主义和集体主义维度上的相似度分数
for word, ind_sim, col_sim in zip(word_list, individualism_similarity, collectivism_similarity):
    print(f"Word: {word}, Individualism Similarity: {ind_sim:.2f}, Collectivism Similarity: {col_sim:.2f}")

# 绘制词汇与个体主义和集体主义的相似度散点图
plt.scatter(individualism_similarity, collectivism_similarity, color='blue', label='Vocabulary')
plt.scatter(individualism_similarity[2], collectivism_similarity[2], color='red', label='友情', s=100, marker='x')  # 以友情词汇为红色叉号

# 添加连线和词汇标签
for i, word in enumerate(words_to_v):
    if i != 2:  # 跳过信任词汇本身
        plt.arrow(individualism_similarity[2], collectivism_similarity[2], individualism_similarity[i] - individualism_similarity[2], collectivism_similarity[i] - collectivism_similarity[2], head_width=0.02, color='gray', alpha=0.5)
        plt.annotate(word, (individualism_similarity[i], collectivism_similarity[i]), textcoords="offset points", xytext=(0,10), ha='center',fontproperties=chinese_font)

# 设置图标题和轴标签
plt.title('自私与奉献',fontproperties=chinese_font)
plt.xlabel('自私',fontproperties=chinese_font)
plt.ylabel('奉献',fontproperties=chinese_font)
#设置带颜色的二维图
freedom_vector = word_vectors['自由']

# 添加自由维度的相似度
freedom_similarity = [cosine_similarity([freedom_vector], [word_vectors[word]])[0][0] for word in word_list]

# 绘制词汇与个体主义和集体主义的相似度散点图
plt.scatter(individualism_similarity, collectivism_similarity, c=freedom_similarity, cmap='coolwarm', label='Vocabulary')
plt.scatter(individualism_similarity[2], collectivism_similarity[2], color='red', label='Trust', s=100, marker='x')  # 以信任词汇为红色叉号

# 添加连线和词汇标签
for i, word in enumerate(words_to_v):
    if i != 2:  # 跳过信任词汇本身
        plt.arrow(individualism_similarity[2], collectivism_similarity[2], individualism_similarity[i] - individualism_similarity[2], collectivism_similarity[i] - collectivism_similarity[2], head_width=0.02, color='gray', alpha=0.5)
        plt.annotate(word, (individualism_similarity[i], collectivism_similarity[i]), textcoords="offset points", xytext=(0,10), ha='center')

# 设置颜色标签
cb = plt.colorbar()
cb.set_label('Freedom Similarity', rotation=270, labelpad=15)

# %%
import plotly.graph_objects as go
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Line3DCollection
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Line3D
# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制个体主义、集体主义和自由三个维度的散点图
ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c='green', marker='o', label='Vocabulary')

# 添加词汇标签
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i], word,fontproperties=chinese_font)

# 设置坐标轴标签字体
ax.set_xlabel('自私', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'},fontproperties=chinese_font)
ax.set_ylabel('奉献', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'},fontproperties=chinese_font)
ax.set_zlabel('自由', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)





# 设置图表标题

plt.title('Three-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'},fontproperties=chinese_font)

# ... 其他代码 ...

plt.show()


#带颜色的三维图
f_vector = word_vectors['约束']


print(f_similarity)
# 添加自由维度的相似度
f_similarity = [cosine_similarity([f_vector], [word_vectors[word]])[0][0] for word in word_list]
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.font_manager import FontProperties

# ... 其他代码 ...

# 创建三维图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

similarities = [
    ('个体主义', individualism_similarity),
    ('集体主义', collectivism_similarity),
    ('自由', freedom_similarity)
]

# 绘制个体主义、集体主义和自由三个维度的散点图
scatter = ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c=f_similarity, marker='o', label='生气', cmap='plasma')

# 添加词汇标签
for i, word in enumerate(words_to_v):
    ax.text(individualism_similarity[i], collectivism_similarity[i], freedom_similarity[i], word, fontproperties=chinese_font)

# 设置坐标轴标签字体
ax.set_xlabel('自私', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_ylabel('奉献', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)
ax.set_zlabel('自由', fontdict={'fontsize': 12, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)

# 调整观察角度
ax.view_init(elev=50, azim=-45)

# 设置图表标题
plt.title('Five-Dimensional Vocabulary Visualization', fontdict={'fontsize': 16, 'fontweight': 'bold'}, fontproperties=chinese_font)

# 添加图例
ax.legend(prop=chinese_font)

# 显示颜色映射
cbar = plt.colorbar(scatter)
cbar.set_label('Fifth Dimension', fontdict={'fontsize': 0.2, 'fontweight': 'bold', 'color': 'grey'}, fontproperties=chinese_font)

# ... 其他代码 ...

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6b03ad95154f> in <module>
#      13
#      14 # 绘制个体主义、集体主义和自由三个维度的散点图
# ---> 15 ax.scatter(individualism_similarity, collectivism_similarity, freedom_similarity, c='green', marker='o', label='Vocabulary')
#      16
#      17 # 添加词汇标签
#
# NameError: name 'individualism_similarity' is not defined

# %%
#打印余选值
#['爱情', '友情', '亲情', '快乐', '伤心', '信任', '金钱']
# 计算词向量之间的余弦相似度
# 示例词汇
word_list_try = ['恋爱', '友情', '家', '快乐', '伤心', '信任', '金钱']  # 你的词汇列表

# 加载个体主义和集体主义的词向量
individualism_vector = word_vectors['自私']
collectivism_vector_ter = word_vectors['牺牲']

# 计算词汇与个体主义和集体主义的相似度
individualism_similarity = [cosine_similarity([individualism_vector], [word_vectors[word]])[0][0] for word in word_list]
collectivism_similarity_try = [cosine_similarity([collectivism_vector], [word_vectors[word]])[0][0] for word in word_list_try]
print(collectivism_similarity_try)
# 计算两个词的相似度/相关程度
try:
    y1 = word_vectors.similarity( u"牺牲",u"恋爱")
except KeyError:
    y1 = 0
print(u"【社科院】和【社会学】的相似度为：", y1)
print("-----\n")
# Out:
# [0.2212301, 0.3689043, 0.10749957, 0.26037288, 0.25057295, 0.3206204, 0.34210354]
# 【社科院】和【社会学】的相似度为： 0.27456945
# -----

# %% [markdown]
# 内部评估
# 内部评价指的是用词的词性，相关性等内部固有关系来评价生成的词向量的好坏。外部评价指的是用生成的词向量去作为下游任务的输入，看哪种词向量可 以更好的实现下游任务。内在评估又可以分为绝对内部评价（absolute intrinsic evaluation）和相对的内部评价（comparative intrinsic evaluation）。
#
# 绝对内在评估
# 绝对内在评估直接衡量给定两个单词之间的句法和语义关系。共有四种类型的评价：
#
# 相关性（Relatedness）：比较生成的词向量的词与词之间的余弦相似度和人类评价的相似度的关系
#
# 类比性（Analogy）：对于一个y，去找到一个x，使得x:y的关系要和a:b的关系一样
#
# 分类（Categorization）：把生成的词向量做聚类，看聚类是否准确
#
# 选择偏好（Selectional preference）：确定一个词是某个动词的主语还是宾语
#
# 相关性(Relatedness)
# 对于两个单词，他们之间的余弦相似度应该和人类主观评价的得分有较高的相关性。即评价词向量模型在两个词之间的语义相关性，如：学生与作业，中国与北京等。具体方法由监督模式实现，首先需要一份如下的标记文件，一般可以由人工标注：
# 学生 上课 0.78
#
# 教师 备课 0.8
#
# ...
#
# 上述文件代表了词语之间的语义相关性，我们利用标注文件与训练出来的词向量相似度进行比较，如：词向量之间的cos距离等，确定损失函数，便可以得到一个评价指标。
# 但这种方法首先需要人力标注，且标注的准确性对评价指标影响非常大。
# 分类(Categorization)
# 把词聚类成不同的堆，看是否聚类准确。

# %%
定义词典

# %%
class GloveDataset(Dataset):
    def __init__(self, corpus, vocab, context_size=2):
        # 记录词与上下文在给定语料中的共现次数
        self.cooccur_counts = defaultdict(float)
        self.bos = vocab[BOS_TOKEN]  # 句首标记
        self.eos = vocab[EOS_TOKEN]  # 句尾标记
        for sentence in tqdm(corpus, desc="Dataset Construction"):
            sentence = [self.bos] + sentence + [self.eos]
            for i in range(1, len(sentence)-1):
                w = sentence[i]
                left_contexts = sentence[max(0, i - context_size):i]
                right_contexts = sentence[i+1:min(len(sentence), i + context_size)+1]
                # 共现次数随距离衰减: 1/d(w, c)
                for k, c in enumerate(left_contexts[::-1]):
                    self.cooccur_counts[(w, c)] += 1 / (k + 1)
                for k, c in enumerate(right_contexts):
                    self.cooccur_counts[(w, c)] += 1 / (k + 1)
        self.data = [(w, c, count) for (w, c), count in self.cooccur_counts.items()]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        return self.data[i]

    def collate_fn(self, examples):
        words = torch.tensor([ex[0] for ex in examples])
        contexts = torch.tensor([ex[1] for ex in examples])
        counts = torch.tensor([ex[2] for ex in examples])
        return (words, contexts, counts)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from collections import defaultdict
from tqdm import tqdm

BOS_TOKEN = "<BOS>"
EOS_TOKEN = "<EOS>"

class GloveDataset(Dataset):
    def __init__(self, corpus, vocab, context_size=2):
        # 类似上面的代码，计算共现次数并存储在self.data中

    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        return self.data[i]

    def collate_fn(self, examples):
        words = torch.tensor([ex[0] for ex in examples])
        contexts = torch.tensor([ex[1] for ex in examples])
        counts = torch.tensor([ex[2] for ex in examples])
        return (words, contexts, counts)

# 构建一个示例的语料库和词汇表
corpus = [["I", "love", "to", "eat", "pizza"],
          ["Pizza", "is", "delicious"],
          ["I", "enjoy", "eating", "pizza"]]

vocab = {word: idx for idx, word in enumerate(set(word for sentence in corpus for word in sentence))}

# 创建数据集实例
dataset = GloveDataset(corpus, vocab, context_size=2)

# 创建数据加载器
batch_size = 4
data_loader = DataLoader(dataset, batch_size=batch_size, collate_fn=dataset.collate_fn, shuffle=True)

# 打印示例数据批次
for batch in data_loader:
    words, contexts, counts = batch
    print("Words:", words)
    print("Contexts:", contexts)
    print("Counts:", counts)
    break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d8b0f7080b77> in <module>
# ----> 1 import torch
#       2 from torch.utils.data import Dataset, DataLoader
#       3 from collections import defaultdict
#       4 from tqdm import tqdm
#       5
#
# ModuleNotFoundError: No module named 'torch'

# %%
class GloveModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(GloveModel, self).__init__()
        # 词嵌入及偏置向量
        self.w_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.w_biases = nn.Embedding(vocab_size, 1)
        # 上下文嵌入及偏置向量
        self.c_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.c_biases = nn.Embedding(vocab_size, 1)

    def forward_w(self, words):
        w_embeds = self.w_embeddings(words)
        w_biases = self.w_biases(words)
        return w_embeds, w_biases

    def forward_c(self, contexts):
        # 上下文embedding和偏置向量
        c_embeds = self.c_embeddings(contexts)
        c_biases = self.c_biases(contexts)
        return c_embeds, c_biases

# %%
m_max = 100
alpha = 0.75
# 从文本数据中构建GloVe训练数据集
corpus, vocab = load_reuters()
dataset = GloveDataset(
    corpus,
    vocab,
    context_size=context_size
)

def get_loader(dataset, batch_size, shuffle=True):
    data_loader = DataLoader(
        dataset,
        batch_size=batch_size,
        collate_fn=dataset.collate_fn,
        shuffle=shuffle
    )
    return data_loader
data_loader = get_loader(dataset, batch_size)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = GloveModel(len(vocab), embedding_dim)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

model.train()
for epoch in range(num_epoch):
    total_loss = 0
    for batch in tqdm(data_loader, desc=f"Training Epoch {epoch}"):
        words, contexts, counts = [x.to(device) for x in batch]
        # 提取batch内词、上下文的向量表示及偏置
        word_embeds, word_biases = model.forward_w(words)
        context_embeds, context_biases = model.forward_c(contexts)
        # 回归目标值：必要时可以使用log(counts+1)进行平滑
        log_counts = torch.log(counts)
        # 样本权重
        weight_factor = torch.clamp(torch.pow(counts / m_max, alpha), max=1.0)
        optimizer.zero_grad()
        # 计算batch内每个样本的L2损失
        loss = (torch.sum(word_embeds * context_embeds, dim=1) + word_biases + context_biases - log_counts) ** 2
        # 样本加权损失
        wavg_loss = (weight_factor * loss).mean()
        wavg_loss.backward()
        optimizer.step()
        total_loss += wavg_loss.item()
    print(f"Loss: {total_loss:.2f}")

# 合并词嵌入矩阵与上下文嵌入矩阵，作为最终的预训练词向量
combined_embeds = model.w_embeddings.weight + model.c_embeddings.weight
save_pretrained(vocab, combined_embeds.data, "glove.vec")
