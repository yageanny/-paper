# %%
### 导入相关package
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import pandas as pd
from factor_analyzer import FactorAnalyzer

#机器学习模型：
from sklearn import linear_model

import warnings
import statsmodels
import statsmodels.api as sm
warnings.filterwarnings("ignore")
#导入 train_test_split
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE#导入决策树-分类树
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
# 可视化
from six import StringIO
import pydotplus
import graphviz  
from IPython.display import Image
from sklearn import tree
# 使用gridsearch的方法调参
from sklearn.model_selection import GridSearchCV
# 导入所需的库
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import pydotplus
from IPython.display import Image
#调包
from sklearn.tree import DecisionTreeRegressor
from IPython.display import Image,display

# %%
import pandas as pd

# 读取 .dta 文件
dataa = pd.read_stata('D://作业//AMOS 数据//网民风险//2017网民调查最终2379（STATA版）.DTA')

# 显示数据的前几行
print(data.head())
dataa.columns

# %%
dataa = data[[
'Q23_R12m', 'Q23_R13m', 'Q23_R14m', 'Q23_R15m', 'Q23_R16m', 'Q23_R18m', 'Q23_R19m', 'Q23_R23m', 'Q23_R25m', 'Q23_R26m', 'Q23_R27m'
]]
dataa.to_csv('D://作业//AMOS 数据//网民风险//现代传统价值观.csv', index=False)

# %%
df = pd.read_excel('D://作业//AMOS 数据//网民风险//网民调查.xlsx')
#查看数据
print(df.shape)
print("variables: ",list(df.columns))
df.head()

# %%
topic = df[[ '人文知识', '休先阅读', '专业阅读', '政经时事'
     # 删除指定的列'民歌戏曲', '流行歌曲', '摇滚舞曲', '信息渠道', '人文知识', '休先阅读', '专业阅读', '政经时事'
]]
import pandas as pd

# Create a sample DataFrame



# Function to find the column name with the maximum value in each row
def find_max_column(row):
    return row.idxmax()

# Apply the function to each row
topic['影视偏好'] = topic.apply(find_max_column, axis=1)

# Replace the values with the column names
topic['Max_Value'] = topic.apply(lambda row: row[row['影视偏好']], axis=1)

# Display the resulting DataFrame
print(topic)

topic.to_csv('D://作业//AMOS 数据//网民风险//topic_distributions.csv', index=False)

# %%
#df = df.drop(columns=['民歌戏曲', '流行歌曲', 'Q7n', 'Q6年收入','摇滚舞曲', '人文知识', '休先阅读', '专业阅读', '政经时事'])  # 删除指定的列

data['影视偏好'] = topic['影视偏好']  # 创建一个新列将data2的数据合并到data1

data['Max_Value'] = topic['Max_Value']  # 创建一个新列将data2的数据合并到data1
data.columns

# %%
#df.to_csv('D://作业//AMOS 数据//网民风险//影视.csv', index=False)
#data = df.drop(columns=['影视偏好','Max_Value'])
#dataa = data.drop(columns=['影视偏好','Max_Value' , '人文知识', '休先阅读', '专业阅读',
#    '民歌戏曲', '政经时事','Q7n', 'Q6年收入',
#       '流行歌曲', '摇滚舞曲', 
#      ])
dataaa = dataa[['ln_wage', 
              '信息渠道','Extraversion', 'Agreeableness', 'Conscientiousness', 'Neuroticism', 'Closedmindness', 
               'Q15_R10','Q15_R11' ,'政治意识','Q15_R12' ,'Q15_R13', 'Q15_R14', 'Q15_R15', 'Q15_R16', 
               'Q17','Q18_R1','Q18_R3',  'Q18_R4', 'Q18_R5', 'Q18_R6', 'Q18_R7', 'Q18_R8','Q15_R18', 'Q15_R19', 'Q15_R20', 'Q15_R21', 'Q15_R22', 'Q1', 'Q2', 'Q4', 'Q5', '政治意识水平', 'Q8', 'Q9', 'Q7n',
              'Authoritarian', 'nationalism', '民歌戏曲', '流行歌曲', '摇滚舞曲', '信息渠道', '人文知识', '休先阅读', '专业阅读', '政经时事', '性别', '教育', '教育水平2', '家庭年收入', '党员', '左中右因子', 'Q60_R1n', 'Q60_R2n', 'Q60_R3n', 'Q60_R4n'
              ,'Q60_R5n', 'Q60_R6n', '精英群体1', '精英群体2', '精英群体3', '精英群体4',"服从", '现代新思想' ]]

#data = df.drop(columns=['Q7n', 'Q6年收入'])
#data = data.drop(columns=['精英群体1', '精英群体2', '精英群体3', '精英群体4','家庭年收入','ln_wage', '教育',
     # Q60_R2n','Q7n', 'Q6年收入',,'Q60_R1n'
#       '精英群体4''教育水平2' 'Q60_R3n', 'Q60_R4n', 'Q60_R5n', 'Q60_R6n', '精英群体1', '精英群体2', '精英群体3',])

dataaa.to_csv('D://作业//AMOS 数据//网民风险//dataa.csv', index=False)
dataaa.columns

# %%
variables = data[['Q23_R12m', 'Q23_R19m', 'Q23_R16m','Q23_R18m','Q23_R25m']]  # 替换成你的变量名称
factortor.to_csv('D://作业//AMOS 数据//网民风险//因子分析.csv', index=False)
factortor = data[['Q23_R12m',"Q23_R13m",'Q23_R14m','Q23_R15m','Q23_R16m','Q23_R17m','Q23_R18m','Q23_R19m','Q23_R21m','Q23_R22m','Q23_R23m','Q23_R25m','Q23_R26m',"Q23_R27m"]]

# %%
variables['我喜欢和有不同思想的人交流，也能容忍不同意见'] = variables['Q23_R12m'].map({'强烈反对': 1, '反对': 2, '中立': 3, '同意': 4, '非常同意': 5})
variables['强硬的政府和严刑酷法并不能解决当前的各种社会问题'] = variables['Q23_R16m'].map({'强烈反对': 5, '反对': 4, '中立': 3, '同意': 2, '非常同意': 1})
variables['同性恋婚姻和异性婚姻一样应该受到法律保护'] = variables['Q23_R18m'].map({'强烈反对': 1, '反对': 2, '中立': 3, '同意': 4, '非常同意': 5})
variables['两个成年人之间自愿的性行为是其自由，无论其有没有婚'] = variables['Q23_R19m'].map({'强烈反对': 1, '反对': 2, '中立': 3, '同意': 4, '非常同意': 5})
variables['我们要致力于建设一个人人平等的社会'] = variables['Q23_R25m'].map({'强烈反对': 1, '反对': 2, '中立': 3, '同意': 4, '非常同意': 5})

# %%
variables = variables[['我喜欢和有不同思想的人交流，也能容忍不同意见','强硬的政府和严刑酷法并不能解决当前的各种社会问题',
                       '同性恋婚姻和异性婚姻一样应该受到法律保护','两个成年人之间自愿的性行为是其自由，无论其有没有婚',
                       '我们要致力于建设一个人人平等的社会']]

# %%
fa = FactorAnalyzer(n_factors=2, rotation='varimax')
fa.fit(variables)
# 因子载荷
factor_loadings = fa.loadings_
kmo = fa.get_kmo()
bartlett = fa.calculate_bartlett_sphericity()
fa.rotate_factors('varimax')  # 替换成你选择的旋转方法
explained_variance = fa.get_factor_variance()

# %%
factor_loadings

# %%
#定义feature 和 label
feature=['ln_wage', 'Q33_R2','Q33_R6','Q33_R5','Q33_R4','Q33_R3','Q33_R1','raversion', 'Agreeableness', 'Conscientiousness',
       'Neuroticism', 'Closedmindness', 'Authoritarian', 'nationalism', '信息渠道',
       '性别', '教育', '教育水平2', '家庭年收入', '党员', '左中右因子',  '精英群体1', '精英群体2', '精英群体3', '精英群体4']
label=['Q33_R2']

inputs=df[feature]
labels=df[label]

#划分训练集和测试集
(train_X,
 test_X,
 train_y,
 test_y) = train_test_split(inputs, labels, train_size=0.3, random_state=5029)

#看一下数据集长什么样子
print(train_X.shape,test_X.shape,)
train_X.head(1)

# %%
df['影视偏好'].unique()

# %%
# 使用决策树预测kmeans聚类的类别
df['Q33_R2'].unique()
#划分数据集
# 假设'y_variable'是你的y变量列名

all_inputs =df[list(data.columns)].values
all_classes =data['Q33_R2'].values
(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.5, random_state=1)

#定义决策树模型
decision_tree_classifier = DecisionTreeClassifier(random_state=210)
#在训练集上训练模型
decision_tree_classifier.fit(training_inputs, training_classes)
#在测试集上测试
# Validate the classifier on the testing set using classification accuracy
s=decision_tree_classifier.score(testing_inputs, testing_classes)  #在测试集上的准确性
print('准确性:',s)

# %%
# 决策树具有一定的随机性，多运行几次看看

# 100个模型的预测准确率
scors=list() #定义一个空的集合来储存每次的预测准确性
for i in range(0,100):
    (training_inputs,
     testing_inputs,
     training_classes,
     testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.5, random_state=210)
    decision_tree_classifier = DecisionTreeClassifier(random_state=i)
    #训练模型
    # Train the classifier on the training set
    decision_tree_classifier.fit(training_inputs, training_classes)
    #所得模型的准确性
    # Validate the classifier on the testing set using classification accuracy
    s=decision_tree_classifier.score(testing_inputs, testing_classes)
    scors.append(s)
    #看100次准确性的分布
scors=np.array(scors)
print('准确性:',scors.mean(),'准确性误差:',scors.std())

# %%
#预测准确性可视化
fig, (ax1) = plt.subplots(1,1, figsize=(10,5))
ax1=sns.barplot(list(range(0,100)),scors)
ax1.set_xlabel("accuracy",fontsize=10)
ax1.set_ylabel("number of models",fontsize=20)
ax1.set_title("accuracy distribution of 100 models",fontsize=20)
plt.ylim([0.5, 1])
plt.show()

# %%
#区分训练集、测试集
(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.5, random_state=1)

# %%
df['精英群体4'].unique()

# %%
#----不剪枝

#定义决策树模型
dtc = DecisionTreeClassifier(random_state=20)
#在训练集上训练模型
dtc.fit(training_inputs, training_classes)
#在测试集上测试
# Validate the classifier on the testing set using classification accuracy
s=dtc.score(testing_inputs, testing_classes)  #在测试集上的准确性
print(s)
# 要定义特征的标签和类别标签
data_feature_name = list(data.columns)
data_target_name = ['专业阅读', '休先阅读', '人文知识', '政经时事']

#不剪枝
dt = tree.export_graphviz(dtc,out_file=None,
                                feature_names=data_feature_name,
                                class_names=data_target_name,
                                filled=True, 
                                rounded=True,
                                special_characters=True,
                                fontname="arial.ttf")
graph1 = pydotplus.graph_from_dot_data(dt)
img1 = Image(graph1.create_png())
graph1.write_png("pics/不减枝.png")

# %%
#-----剪枝
dt = DecisionTreeClassifier(random_state=20,
                            max_depth=3,         #树的最大深度
                            min_samples_split=20,  #样本数量大于多少才能进行下一步分枝
                            min_samples_leaf=10,    #叶子节点中样本数的最小值
                            min_weight_fraction_leaf=0,  #叶子节点所有样本权重和的最小值
                            max_leaf_nodes=None,   #最大的叶子节点的个数
                            min_impurity_decrease=0)   #最小的不纯度（基尼系数、信息增益等）

#训练模型
# Train the classifier on the training set
dt.fit(training_inputs, training_classes)
#所得模型的准确性
# Validate the classifier on the testing set using classification accuracy
s=dt.score(training_inputs, training_classes)
print(s)
cut_tree = tree.export_graphviz(dt,out_file=None,
                                feature_names=data_feature_name,
                                class_names=data_target_name,filled=True, 
                                rounded=True,
                                special_characters=True,
                                fontname='arial.ttf')
graph1 = pydotplus.graph_from_dot_data(cut_tree)
img1 = Image(graph1.create_png())
graph1.write_png("pics/减枝.png")

# %%
#决策树特征重要性

#定义决策树模型
dtc = DecisionTreeClassifier(random_state=20)
#在训练集上训练模型
dtc.fit(training_inputs, training_classes)
importance=list(dtc.feature_importances_)

# %%
impd=pd.DataFrame(list(zip(data.columns,importance)), 
                   columns = ['variable', 'importance'])

# %%
impd

# %%
#特征重要性可视化
plt.figure(figsize=(10,10))
sns.barplot(impd['importance'],impd['variable'])

plt.title("feature importance",fontsize=20,)
plt.show()

# %%
#设置参数空间
param_test1 = {'max_features':range(4,len(data.columns)+1),   #使用多少feature来预测
               'max_depth':range(3,6,1),        # 树的深度      
               'min_samples_leaf':range(10,200,50),  #叶子最小样本数
               }

X=all_inputs
y=all_classes

grid=[]
gsearch = GridSearchCV(
           estimator = DecisionTreeClassifier(
                                              random_state=20,        
                                              #min_samples_leaf=30

                                              ), 
                   param_grid = param_test1,          
                   refit=True,
                   #scoring='roc_auc',                   
                   cv=5)  # 十折交叉验证
#拟合模型
gsearch.fit(X,y)
#保存结果
grid={"best_params":gsearch.best_params_, 
          "best_score":gsearch.best_score_,
          "cv_results":gsearch.cv_results_,
          "best_estimator":gsearch.best_estimator_,
          "best_index":gsearch.best_index_,
          "scorer":gsearch.scorer_,
          #"feature_names":feature_names_in_
          }

#打印最好模型的参数设置和准确性
print(gsearch.best_params_, gsearch.best_score_)

# %%
data.columns

# %%
# 导入所需的库
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import pydotplus
from IPython.display import Image

# 定义决策树模型并设置超参数
dtc = DecisionTreeClassifier(max_depth=5, max_features=18, min_samples_leaf=10, random_state=20)

# 在训练集上训练模型
dtc.fit(training_inputs, training_classes)

# 可视化决策树
dot_data = export_graphviz(
    dtc,
    out_file=None,
    feature_names=data_feature_name,
    class_names=data_target_name,
    filled=True,
    rounded=True,
    special_characters=True,
    fontname="arial.ttf"
)

graph = pydotplus.graph_from_dot_data(dot_data)
img = Image(graph.create_png())
graph.write_png("pics/最佳模型.png")

# %%
predicted_classes = dtc.predict(training_inputs)
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(training_classes, predicted_classes)
print(f"模型的准确性：{accuracy:.2f}")

# %% [markdown]
# 回归

# %%
#df.to_csv('D://作业//AMOS 数据//网民风险//影视.csv', index=False)
#data = df.drop(columns=['影视偏好','Max_Value'])
#dataa = data.drop(columns=['影视偏好','Max_Value' , '人文知识', '休先阅读', '专业阅读',
#    '民歌戏曲', '政经时事','Q7n', 'Q6年收入',
#       '流行歌曲', '摇滚舞曲', 
#      ])
dataa = data[['Q26', 'Q27','ln_wage', 'Q33_R2','Q33_R6','Q33_R5','Q33_R4','Q33_R3','Q33_R1', 'Agreeableness', 'Conscientiousness',
       'Neuroticism', 'Closedmindness', 'Authoritarian', 'nationalism', '信息渠道',
       '性别', '教育', '教育水平2', '家庭年收入', '党员', '左中右因子', 'Q60_R1n', 'Q60_R2n',
       'Q60_R3n', 'Q60_R4n', 'Q60_R5n', 'Q60_R6n', '精英群体1', '精英群体2', '精英群体3',
       '人文知识', '休先阅读', '专业阅读', '民歌戏曲', '流行歌曲', '摇滚舞曲', '精英群体4']]
#data = df.drop(columns=['Q7n', 'Q6年收入'])
#data = data.drop(columns=['精英群体1', '精英群体2', '精英群体3', '精英群体4','家庭年收入','ln_wage', '教育',
     # Q60_R2n','Q7n', 'Q6年收入',,'Q60_R1n'
#       '精英群体4''教育水平2' 'Q60_R3n', 'Q60_R4n', 'Q60_R5n', 'Q60_R6n', '精英群体1', '精英群体2', '精英群体3',])
dataa.columns
#dataa.to_csv('D://作业//AMOS 数据//网民风险//dataa.csv', index=False)

# %%
import pandas as pd
import statsmodels.api as sm
#导入RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
data = pd.read_excel('D://作业//AMOS 数据//网民风险//总体.xlsx')
data.columns
#定义feature 和 label


# 定义自变量 x，注意使用列表包含多个列名
feature = [['性别', '教育水平', '年龄', '信息渠道 (1)', '流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读',
       '人文知识', '摇滚舞曲', '认知封闭性', '宜人性', '尽责性', '神经质', '外向型', '购买报纸阅读时政新闻',
       '观看各地方电视台的时政新闻节目', '央视、新华社、人民日报的时政分析报道（含微博及微信公',
       '天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖']]
label = ['对权威的不服从']

inputs= [list(feature.columns)].values
labels=data[label]

#划分训练集和测试集
(train_X,
 test_X,
 train_y,
 test_y) = train_test_split(inputs, labels, train_size=0.3, random_state=5029)

#看一下数据集长什么样子
print(train_X.shape,test_X.shape,)
train_X.head(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-602a5415e590> in <module>
#      15 label = ['对权威的不服从']
#      16
# ---> 17 inputs= data[list(feature.columns)].values
#      18 labels=data[label]
#      19
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
# 定义因变量 y
y = data['对权威的不服从']

# 定义自变量 x，注意使用列表包含多个列名
x = data[['性别', '教育水平', '年龄', '信息渠道 (1)', '流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读',
       '人文知识', '摇滚舞曲', '认知封闭性', '宜人性', '尽责性', '神经质', '外向型', '购买报纸阅读时政新闻',
       '观看各地方电视台的时政新闻节目', '央视、新华社、人民日报的时政分析报道（含微博及微信公',
       '天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖']]

# 添加截距项
x = sm.add_constant(x)

# 构建OLS回归模型并拟合
model = sm.OLS(y, x).fit()

# 输出回归结果
print(model.summary())

# %%
#回归树
inputs=dataa[feature]
labels=dataa[label]

#划分训练集和测试集
(train_X,
 test_X,
 train_y,
 test_y) = train_test_split(inputs, labels, train_size=0.5, random_state=5029)


#定义回归决策树对象
regs = DecisionTreeRegressor(random_state=20,
                             max_depth=3,
                            min_samples_split=20,  #样本数量大于多少才能进行下一步分枝
                            min_samples_leaf=10,  )  #叶子节点中样本数的最小值)
#在训练集上训练模型
regs.fit(train_X, train_y)
#在测试集上预测y
y_pred=regs.predict(test_X)

print(MSE(test_y['Q33_R2'],y_pred))

# %% [markdown]
# #展示图

# %%
# 使用决策树预测kmeans聚类的类别
import pandas as pd
import statsmodels.api as sm
#导入RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
# 导入所需的库
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

# 读取数据
data = pd.read_excel('D://作业//AMOS 数据//网民风险//总体.xlsx')

# 选择特征和目标变量
dat = data[['性别', '教育水平', '年龄', '信息渠道 (1)', '流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读', '人文知识', '摇滚舞曲', '认知封闭性', '宜人性', '尽责性', '神经质', '外向型', '购买报纸阅读时政新闻', '观看各地方电视台的时政新闻节目', '央视、新华社、人民日报的时政分析报道（含微博及微信公', '天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖']]
target = data['对权威的不服从']

# 划分数据集
(training_inputs, testing_inputs, training_target, testing_target) = train_test_split(dat, target, train_size=0.5, random_state=1)

# 定义GBM回归模型
gradient_boosting_regressor = GradientBoostingRegressor(random_sGradientBoostingRegressortate=210)

# 在训练集上训练模型
gradient_boosting_regressor.fit(training_inputs, training_target)

# 在测试集上测试
predictions = gradient_boosting_regressor.predict(testing_inputs)

# 计算回归模型的性能指标
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(testing_target, predictions)
r2 = r2_score(testing_target, predictions)

print("均方误差 (MSE):", mse)
print("决定系数 (R^2):", r2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-72436c04e21a> in <module>
#      23
#      24 # 定义GBM回归模型
# ---> 25 gradient_boosting_regressor = GradientBoostingRegressor(random_sGradientBoostingRegressortate=210)
#      26
#      27 # 在训练集上训练模型
#
# TypeError: __init__() got an unexpected keyword argument 'random_sGradientBoostingRegressortate'

# %%
from sklearn.metrics import mean_squared_error, r2_score

num_iterations = 100  # 设置迭代次数
scors = []  # 用于存储每次迭代的性能得分

for i in range(num_iterations):
    (training_inputs, testing_inputs, training_outputs, testing_outputs) = train_test_split(all_inputs, target, train_size=0.5, random_state=i)

    decision_tree_regressor = GradientBoostingRegressor(random_state=i)

    # 训练模型
    decision_tree_regressor.fit(training_inputs, training_outputs)

    # 在测试集上进行预测
    predictions = decision_tree_regressor.predict(testing_inputs)

    # 评估模型性能
    mse = mean_squared_error(testing_outputs, predictions)
    r2 = r2_score(testing_outputs, predictions)
    scors.append(r2)

    #print(f"Iteration {i + 1} - Mean Squared Error: {mse}, R-squared: {r2}")

# 打印所有迭代的性能分数
#print("All R-squared Scores:", scors)

# %%
#决策树特征重要性

#定义决策树模型
dtc = DecisionTreeClassifier(random_state=20)
#在训练集上训练模型
dtc.fit(training_inputs, training_classes)
importance=list(dtc.feature_importances_)
impd=pd.DataFrame(list(zip(data.columns,importance)), 
                   columns = ['variable', 'importance'])
impd

# %%
data = pd.read_excel('D://作业//自然语言处理//AMOS 数据//网民风险//总体.xlsx')

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
#导入RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
# 导入所需的库
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
#
data = data.dropna()

# 选择特征和目标变量
cols = ['性别', '教育水平', '年龄', '信息渠道 (1)', '流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读', '人文知识', '摇滚舞曲', '认知封闭性', '宜人性', '尽责性', '神经质', '外向型', '购买报纸阅读时政新闻', '观看各地方电视台的时政新闻节目', '央视、新华社、人民日报的时政分析报道（含微博及微信公', '天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖']
y = data['对权威的不服从']

# 选择特征和目标变量
dat = data[['性别', '教育水平', '年龄', '信息渠道 (1)', '流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读', '人文知识', '摇滚舞曲', '认知封闭性', '宜人性', '尽责性', '神经质', '外向型', '购买报纸阅读时政新闻', '观看各地方电视台的时政新闻节目', '央视、新华社、人民日报的时政分析报道（含微博及微信公', '天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖']]
target = data['对权威的不服从']

# 划分数据集
(training_inputs, testing_inputs, training_target, testing_target) = train_test_split(dat, target, train_size=0.5, random_state=1)

# 指定GBM模型参数
model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=4, random_state=None)

# 使用模型训练数据
model.fit(data[cols], y)

importance = list(model.feature_importances_)

# 创建包含元组的列表，每个元组包含变量名和其重要性值
impd = [(cols[i], importance[i]) for i in range(len(cols))]

# 按照重要性降序排序
impd = sorted(impd, key=lambda x: x[1], reverse=True)

# 选择前20个重要的变量
top_20_features = impd[:20]

# 特征重要性可视化
# 设置中文显示的字体，例如SimHei
plt.rcParams['font.sans-serif'] = ['SimHei']

# 设置字体大小
plt.rcParams['font.size'] = 12
plt.figure(figsize=(10, 10))
sns.barplot(x=[x[1] for x in top_20_features], y=[x[0] for x in top_20_features])
plt.title("Feature Importance", fontsize=20)
plt.show()

#在训练集上训练模型
model.fit(training_inputs, training_target)
importance=list(model.feature_importances_)

impd = pd.DataFrame(list(zip(data.columns, importance)),
                   columns=['variable', 'importance'])

# 按照重要性降序排序
impd = impd.sort_values(by='importance', ascending=False)

# 选择前20个重要的变量
top_20_features = impd.head(20)

top_20_features
# Out:
#                       variable  importance
# 10                        摇滚舞曲    0.237911
# 5                         民歌戏曲    0.122301
# 11                       认知封闭性    0.093137
# 9                         人文知识    0.080642
# 6                         政经时事    0.057086
# 4                         流行歌曲    0.049504
# 13                         尽责性    0.047093
# 8                         休先阅读    0.043822
# 7                         专业阅读    0.041785
# 15                         外向型    0.037523
# 17             观看各地方电视台的时政新闻节目    0.031347
# 2                           年龄    0.026925
# 14                         神经质    0.025087
# 12                         宜人性    0.025041
# 16                  购买报纸阅读时政新闻    0.023411
# 18  央视、新华社、人民日报的时政分析报道（含微博及微信公    0.017715
# 3                     信息渠道 (1)    0.015975
# 19  天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖    0.010411
# 1                         教育水平    0.007086
# 0                           性别    0.006198

# %%
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import shap
# model是在第1节中训练的模型
explainer = shap.TreeExplainer(model)
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(data[cols])
print(shap_values.shape)
y_base = explainer.expected_value
print(y_base)

data['pred'] = model.predict(data[cols])
print(data['pred'].mean())
# Out:
# (2341, 20)
# [-0.04824781]
# -0.03535899691711041

# %%
#单个# 比如我们挑选数据集中的第30位
j = 30
player_explainer = pd.DataFrame()
player_explainer['feature'] = cols
player_explainer['feature_value'] = data[cols].iloc[j].values
player_explainer['shap_value'] = shap_values[j]
player_explainer
print('y_base + sum_of_shap_values: %.2f'%(y_base + player_explainer['shap_value'].sum()))
print('y_pred: %.2f'%(data['pred'].iloc[j]))
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[j], data[cols].iloc[j])
# Out:
# y_base + sum_of_shap_values: -0.52
# y_pred: -0.52
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import shap
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.style.use('seaborn')
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(data[cols])
print(shap_values.shape)
# Out:
# The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
# (2341, 20)

# %%
y_base = explainer.expected_value
print(y_base)

data['pred'] = model.predict(data[cols])
print(data['pred'].mean())
# Out:
# [-0.04824781]
# -0.03596437840232278

# %%
shap.summary_plot(shap_values, data[cols])
#plt.rcParams['font.sans-serif'] = ['SimHei']

# 设置字体大小
plt.rcParams['font.size'] = 12
data.columns
plt.rcParams['font.sans-serif'] = ['SimHei']

# 设置字体大小
plt.rcParams['font.size'] = 12
# Out:
# Glyph 25945 (\N{CJK UNIFIED IDEOGRAPH-6559}) missing from current font.
# Glyph 32946 (\N{CJK UNIFIED IDEOGRAPH-80B2}) missing from current font.
# Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
# Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
# Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
# Glyph 28079 (\N{CJK UNIFIED IDEOGRAPH-6DAF}) missing from current font.
# Glyph 31038 (\N{CJK UNIFIED IDEOGRAPH-793E}) missing from current font.
# Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
# Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
# Glyph 20975 (\N{CJK UNIFIED IDEOGRAPH-51EF}) missing from current font.
# Glyph 36842 (\N{CJK UNIFIED IDEOGRAPH-8FEA}) missing from current font.
# Glyph 38081 (\N{CJK UNIFIED IDEOGRAPH-94C1}) missing from current font.
# Glyph 34880 (\N{CJK UNIFIED IDEOGRAPH-8840}) missing from current font.
# ...

# %%
shap.dependence_plot('天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖', shap_values, data[cols], interaction_index=None, show=False)
plt.rcParams['font.sans-serif'] = ['SimHei']

# 设置字体大小
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False
#'认知封闭性', '宜人性', '尽责性', '神经质', '外向型'
#'购买报纸阅读时政新闻', '观看各地方电视台的时政新闻节目', '央视、新华社、人民日报的时政分析报道（含微博及微信公', '天涯社区、凯迪社区、铁血社区等专业论坛或网站的时政帖'

# %%
shap_interaction_values = shap.TreeExplainer(model).shap_interaction_values(data[cols])
shap.summary_plot(shap_interaction_values, data[cols], max_display=6)

# %%
# 选择第五个到第十个列
cols_to_show = data.columns[5:11]

# 计算交互影响值
shap_interaction_values = shap.TreeExplainer(model).shap_interaction_values(data[cols_to_show])

# 展示交互影响图
shap.summary_plot(shap_interaction_values, data[cols_to_show], max_display=6)
# Out:
# Canceled future for execute_request message before replies were done
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。请查看单元格中的代码，以确定故障的可能原因。有关详细信息，请单击 <a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>。有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
shap.dependence_plot("民歌戏曲", shap_values, data[cols], interaction_index='摇滚舞曲', show=False)
plt.rcParams['font.sans-serif'] = ['SimHei']

# 设置字体大小
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False

# %%
print('Computing partial dependence plots...')
tic = time()
features = ['MedInc', 'AveOccup', 'HouseAge', 'AveRooms']
display = plot_partial_dependence(
       est, X_train, features, kind="individual", subsample=50,
       n_jobs=3, grid_resolution=20, random_state=0
)
# average / individual 

print(f"done in {time() - tic:.3f}s")
display.figure_.suptitle(
    'Individual Conditional Expectation Plot\n'
)
display.figure_.subplots_adjust(hspace=0.3)

# %%
from sklearn.inspection import plot_partial_dependence

# Specify the indices or feature names for the features you want to generate partial dependence plots for
features_to_plot = ['流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读', '人文知识']  # Replace with the indices of the features you want to plot or use feature names

# Generate individual partial dependence plots for the selected features
fig, ax = plot_partial_dependence(model, training_inputs, features_to_plot, grid_resolution=20)

# Display the individual partial dependence plots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-5d69282cf598> in <module>
# ----> 1 from sklearn.inspection import plot_partial_dependence
#       2
#       3 # Specify the indices or feature names for the features you want to generate partial dependence plots for
#       4 features_to_plot = ['流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读', '人文知识']  # Replace with the indices of the features you want to plot or use feature names
#       5
#
# ImportError: cannot import name 'plot_partial_dependence' from 'sklearn.inspection' (d:\ProgramData\Anaconda3\lib\site-packages\sklearn\inspection\__init__.py)

# %%
from pdpbox import pdp, get_dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-3fa56d346ef1> in <module>
# ----> 1 from pdpbox import pdp, get_dataset
#
# ModuleNotFoundError: No module named 'pdpbox'

# %%
from pdpbox import pdp, get_dataset

# For a specific feature
features_to_plot = ['流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读', '人文知识']  # Replace with the indices of the features you want to plot or use feature names

# Create the partial dependence plot for the specified feature
pdp_feature = pdp.pdp_isolate(model=model, dataset=training_inputs, model_features=training_inputs.columns, feature=feature_to_plot)
pdp.pdp_plot(pdp_feature, feature_to_plot)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-2e98d86ca585> in <module>
# ----> 1 from pdpbox import pdp, get_dataset
#       2
#       3 # For a specific feature
#       4 features_to_plot = ['流行歌曲', '民歌戏曲', '政经时事', '专业阅读', '休先阅读', '人文知识']  # Replace with the indices of the features you want to plot or use feature names
#       5
#
# ModuleNotFoundError: No module named 'pdpbox'

# %%
#pip install pdpbox
from sklearn.datasets import fetch_openml
from itertools import product
from pdpbox import pdp, get_dataset
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-3ce845a56adf> in <module>
#       2 from sklearn.datasets import fetch_openml
#       3 from itertools import product
# ----> 4 from pdpbox import pdp, get_dataset
#       5 import matplotlib.pyplot as plt
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'pdpbox'
